# %% [markdown]
# <a href="https://colab.research.google.com/github/LHEYYUEHUA013/FUNDAI-Lab-PEREZ/blob/main/CS_FUNDAI_2026_Lab1_PEREZ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 1: Environment Onboarding
#
# ## Fundamentals of Artificial Intelligence
#
# **Name:** Vince Lhey G. Perez
# **Course:** BSCS-AI
# **Section:** 2-A
# **Date:** 8/18/2026
#
# **GitHub URL:** https://github.com/LHEYYUEHUA013/FUNDAI-Lab-PEREZ
#
# ## Description
# This laboratory introduces the use of Google Colab and GitHub for AI laboratory activities. It also implements a simple intelligent agent.

# %%
import sys
import datetime

print("Python version:")
print(sys.version)

print("Current date:")
print(datetime.date.today())
# Out:
# Python version:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Current date:
# 2026-08-18

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
folder_path = "/content/drive/MyDrive/2026/FIRST-SEMESTER/AI-EL_FUNDAI/FUNDAI-Lab1"
os.makedirs(folder_path, exist_ok=True)

print("Folder ready:", folder_path)
# Out:
# Folder ready: /content/drive/MyDrive/2026/FIRST-SEMESTER/AI-EL_FUNDAI/FUNDAI-Lab1

# %% [markdown]
# ##Simple Intelligent Agent
#
# This simple agent receives a room condition as a percept and produces and action.
#
# The agent follows a condition-action rule:
#
# - if the room is dirty, the agent cleans.
# - if the room is clean, the agent rests.
# - if the room condition is unknown, the agent inspects.

# %%
def simple_reflex_agent(room_condition):
  """
  A simple reflex agent that decides and action based on the room condition
  """
  room_condition = room_condition.strip().lower()

  if room_condition == "dirty":
    return "CLEAN"
  elif room_condition == "clean":
    return "REST"
  else:
    return "INSPECT"

# %%
percepts = ["dirty","clean","dirty","unknown"]

print("Simple Reflex Agent Test")
print("-" * 30)

for i, percept in enumerate(percepts, start=1):
    action = simple_reflex_agent(percept)
    print(f"percept {i}: {percept:<8}-> Action: {action}")
# Out:
# Simple Reflex Agent Test
# ------------------------------
# percept 1: dirty   -> Action: CLEAN
# percept 2: clean   -> Action: REST
# percept 3: dirty   -> Action: CLEAN
# percept 4: unknown -> Action: INSPECT

# %% [markdown]
# ## Performance Measure
# A simple performance measure gives a score when the agent chooses the correct action for the given percept.

# %%
score = 0
total = len(percepts)

for percept in percepts:
    action = simple_reflex_agent(percept)

    if percept == "dirty" and action == "CLEAN":
      score += 1
    elif percept == "clean" and action == "REST":
      score += 1
    elif percept == "unknown" and action == "INSPECT":
      score += 1
print(f"Agent score: {score}/{total}")
# Out:
# Agent score: 4/4

# %% [markdown]
# ## Guide Questions and Answers
#
# ### 1. What is an intelligent agent?
# **Answer** An intelligent agent is a system that perceives its environment through sensors and acts upon that environment through actuators
#
# ### 2. What are the sensors and actuators in this simple agent example?
# **Answer** In this example, the sensor input os the room condition percept. The actuator output is the action such as CLEAN, REST, or INSPECT.
#
# ### 3. Why is documentation important in AI laboratory work?
# **Answer** Documentation explains the purpose of the code, shows the results, and helps the instructor evaluate the student's understanding.

# %% [markdown]
# ## Reflection
#
# ### Challenges Encountered
# - There is not that much challenge that I have encountered so far as the steps and inputs are already fixed, however, if I were to identify a challenge, that would be the code and how to understand it like im reading english literature. It took some time for me to digest and connect the dots as how the previously created codes works.
#
# ### What I Learned
# - I learned that in order to be able to create an agent, you will have to identify and imagine as if the product/agent is already existing and working. Think about the key factors and drivers as how to make it work and integrate it in your code.
